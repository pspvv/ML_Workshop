# %% [markdown]
# <a href="https://colab.research.google.com/github/pspvv/ML_Workshop/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Practical Machine Learning - from Basics to Applications Assignment - III

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###1. Basic Line Plot
# o Plot a simple line graph of 𝑦 = 𝑥^2 for 𝑥 values ranging from -10 to 10.
#
#
# o Label the x-axis as "X Values" and the y-axis as "Squared Values."
#
# o Add a title to the graph.

# %%
x = np.arange(-10,11)# Generating values from -10 to 10
y = x**2
plt.plot(x,y) #Plotting a basic line plot
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Line Plot of y = x^2")
plt.show()

# %% [markdown]
# ###2. Bar Plot
# o Create a bar chart showing the marks scored by 5 students:
# ['Sai', 'Vamsi',
# 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88].
#
# o Add labels to the x-axis and y-axis and give the chart a title.

# %%
plt.bar(['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita'],[85, 90, 78, 92, 88]) #Creating a bar chart with the given data and adding the labels to them
plt.title('Marks Scored by Students')
plt.xlabel('Students')
plt.ylabel('Marks')
plt.show()

# %% [markdown]
# ###3. Scatter Plot
# o Generate two lists of 20 random integers each (for x and y coordinates).

# %%
# Generating two lists of 20 random integers
x = np.random.randint(0,100,20)
y = np.random.randint(0,100,20)
print("Random values")
x,y
# Out:
# Random values
# (array([19, 70, 49, 80, 11, 57, 87, 37, 89, 86, 28, 92, 28, 90,  7, 94, 27,
#         94,  8, 65]),
#  array([86, 81, 67, 88, 58, 13, 15, 39, 50, 86, 42, 75, 12, 65, 41, 49, 19,
#         71, 38,  0]))

# %% [markdown]
# o Create a scatter plot with these values, and customize it by adding color,
# size, and labels to the points.

# %%
plt.scatter(x,y,color='red',s=20,marker="^",label="Data points") # Creating a scatter plot by customising the colour size and adding label to points
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.title("Scatter plot")
plt.legend()
plt.show()

# %% [markdown]
# ###4. Histogram
# o Simulate 100 random values from a normal distribution using
# np.random.randn() and plot a histogram.

# %%
data = np.random.randn(100) #Generating 100 random values from a normal distribution
print("100 random values")
print(data)
# Out:
# 100 random values
# [ 0.50039262 -0.35283529  1.05760058  0.23789573  0.3757932   0.90648996
#   0.91943854  1.19050002 -0.18537804 -1.12124063  0.05028316  0.5157798
#   0.58180296 -0.58073584 -0.85430809 -0.66836028 -0.099881   -0.54857306
#   0.83894706  1.07207754  0.61290699  0.26479237 -0.44092935 -0.93954599
#  -2.22527799  0.25487906  0.84811534  0.68932279  2.1695208   0.22380539
#   1.1179315   0.4333265  -0.68894792 -0.56204445  0.84561068  0.63918021
#  -0.8812704   0.22611656 -0.92885788 -2.11144404 -0.52905903 -0.13881863
#  -0.38897745 -0.4258702   0.57843644  1.39647088 -0.66374216  0.61515576
#  -0.10037746  0.19021027  1.6692949   0.56922509 -1.64263713 -0.17902451
#   0.64172208 -1.45845598  0.39104781  0.21162052 -1.29164276 -0.64753279
#   1.51379745  1.63254084 -0.93558223 -0.87705373 -0.31104684  0.75907739
#  -1.57213072 -0.60421926  1.35410409  1.42519237 -0.60559042 -2.34480266
#   0.94166746  0.7646074   1.20586194  0.06623124  0.16079045  0.41414307
# ...

# %% [markdown]
# o Customize the number of bins and add a grid to the plot.

# %%
plt.hist(data, bins=20, edgecolor='black')# customising the number of bins to be in the plot
plt.grid(True)# Setting up the grid in the plot
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Random Data")
plt.show()

# %% [markdown]
# ###5. Pie Chart
# o Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E']
# with values [20, 30, 25, 15, 10].

# %%
categ=['A', 'B', 'C', 'D', 'E']
val= [20, 30, 25, 15, 10]
print(categ)
print(val)
# Out:
# ['A', 'B', 'C', 'D', 'E']
# [20, 30, 25, 15, 10]

# %% [markdown]
# o Display the percentage values on the chart and use a color palette for
# differentiation.

# %%
plt.pie(val, labels=categ, autopct='%1.1f%%', colors=['red', 'blue', 'green', 'orange', 'purple'])# Displaying the percentage values on the pie chart and using a colour palette
plt.title("Pie Chart of Categories")
plt.show()

# %% [markdown]
# ###6. Box Plot (Seaborn)
# o Create a box plot to visualize the distribution of the marks scored by
# students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73].
#
# o Highlight the median and any outliers.

# %%
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]
# Creating the box plot
sns.boxplot(marks,flierprops=dict(marker='o', color='yellow', markersize=25),
            medianprops=dict(color='red', linewidth=2))
plt.xlabel("Marks")
plt.title("Box Plot of Student Marks")
# Displaying the plot
plt.show()

# %% [markdown]
# ###7. Heatmap (Seaborn)
# o Create a 5x5 matrix with random integers between 1 and 10 using
# np.random.randint() and visualize it as a heatmap using Seaborn.
#
# o Add a color bar and annotate the heatmap with the values.

# %%
data = np.random.randint(1, 11, size=(5, 5)) # Creating a matrix of 5x5 With random integers between 1 and 10
sns.heatmap(data, annot=True, cmap="YlOrRd", fmt="d", linewidths=.5) # Adding colours and annotating the heat map
plt.title("Heatmap")
plt.show()

# %% [markdown]
# ###8. Comparison of Matplotlib and Seaborn

# %%
data = {
    'Category': ['A', 'B', 'C'],
    'Values': [10, 20, 15]
  }
df = pd.DataFrame(data)
print(df)
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        C      15

# %% [markdown]
# o Generate a pair of plots (bar charts or line plots) using the same data in
# both Matplotlib and Seaborn.
#
# o Highlight the differences in the code, syntax, and aesthetics of the two
# libraries.

# %%
# Matplotlib
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.bar(df['Category'], df['Values'], color='blue')
plt.title("Matplotlib Bar Plot")

# Seaborn
plt.subplot(1, 2, 2)
sns.barplot(x='Category', y='Values', data=df, color='green')
plt.title("Seaborn Bar Plot")

# Displaying both plots made by matplotlib on the Seaborn
plt.tight_layout()
plt.show()

# %% [markdown]
# ###9. Pair Plot (Seaborn)
# o Manually create a small dataset with columns such as 'Age', 'Height',
# 'Weight' for 10 individuals and visualize the relationships using a pair plot.

# %%
# Manually creating a small dataset with columns named at age height and weight
data = {'Age': [25, 28, 30, 22, 27, 35, 29, 21, 32, 24],
        'Height': [170, 175, 180, 165, 172, 185, 178, 168, 182, 170],
        'Weight': [70, 75, 80, 65, 72, 85, 78, 68, 82, 70]}
df = pd.DataFrame(data)
print("Sample data")
print(df)
# Visualising the data using a pair plot
sns.pairplot(df)
plt.show()
# Out:
# Sample data
#    Age  Height  Weight
# 0   25     170      70
# 1   28     175      75
# 2   30     180      80
# 3   22     165      65
# 4   27     172      72
# 5   35     185      85
# 6   29     178      78
# 7   21     168      68
# 8   32     182      82
# 9   24     170      70

# %% [markdown]
# ###10. Save and Style Plots
# • Plot any graph of your choice and save it in both .png and .pdf formats.
#
# • Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid') and explain
# how the style impacts the visualization.

# %%
# Generating sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Creating the plot
plt.plot(x, y, label='Sine Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sine Wave Plot')
plt.legend()

# Saving the plot in PNG and PDF formats
plt.savefig('sine_wave_plot.png')
plt.savefig('sine_wave_plot.pdf')
print("Saved successfully")
# By using different styles we can quickly change the appearance of our plots
# To Choose ggplot style-> plt.style.use('ggplot')
sns.set_style("darkgrid")  # Set the style to 'darkgrid'

# Displaying the plot
plt.show()

# We can reset the style of a plot using this method-> sns.reset_orig()
# Out:
# Saved successfully
